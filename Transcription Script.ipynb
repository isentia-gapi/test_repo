# %%
import openai
openai.api_key = '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'
audio_file= open("C:/Users/Rommel/Desktop/part 2.mp3", "rb")
transcript = openai.Audio.translate("whisper-1", audio_file, response_format="vtt")

# %%
translate = transcript

# %%
translate
# Out:
# "WEBVTT\n\n00:00:00.000 --> 00:00:02.000\nIt's so funny, man.\n\n00:00:02.000 --> 00:00:04.000\nIt's hard to explain.\n\n00:00:04.000 --> 00:00:06.000\nIt's so funny.\n\n00:00:06.000 --> 00:00:08.000\nI don't understand.\n\n00:00:08.000 --> 00:00:10.000\nWe have a mission.\n\n00:00:10.000 --> 00:00:12.000\nWe say let's go and then we do the opening.\n\n00:00:12.000 --> 00:00:14.960\nHi, I'm Shakira.\n\n00:00:14.960 --> 00:00:16.960\nAre you listening?\n\n00:00:16.960 --> 00:00:18.960\nOk, let's go.\n\n00:00:18.960 --> 00:00:20.960\nIt's our song.\n\n00:00:20.960 --> 00:00:22.960\nIt's our song.\n\n00:00:22.960 --> 00:00:24.960\nYole, yole, yole.\n\n00:00:24.960 --> 00:00:26.960\nYole, yole, yole.\n\n00:00:26.960 --> 00:00:28.960\nHi, I'm Shakira.\n\n00:00:28.960 --> 00:00:30.960\nHi, I'm Shakira.\n\n00:00:30.960 --> 00:00:32.960\nYou can wear it.\n\n00:00:32.960 --> 00:00:34.960\nWe have a live show.\n\n00:00:34.960 --> 00:00:36.960\nShakira's opening.\n\n00:00:36.960 --> 00:00:38.96
# ...

# %%
audio_file= open("C:/Users/Rommel/Desktop/part 2.mp3", "rb")
transcript_text = openai.Audio.transcribe("whisper-1", audio_file, response_format="vtt")

# %%
transcript_text
